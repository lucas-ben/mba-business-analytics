# %%
def load(data_frame, target_table):
    # loading data from sql
    data_frame.to_sql(name=target_table, con=POSTGRES_CONNECTION)
    print(f"Loading data to the {target_table} table")

extracted_data = extract(file_name="data.csv")
transformed_data = transform(data_frame=extracted_data)
load(data_frame=transformed_data, target_table="cleaned_data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3     data_frame.to_sql(name=target_table, con=POSTGRES_CONNECTION)
#       4     print(f"Loading data to the {target_table} table")
# ----> 6 extracted_data = extract(file_name="data.csv")
#       7 transformed_data = transform(data_frame=extracted_data)
#       8 load(data_frame=transformed_data, target_table="cleaned_data")
#
# NameError: name 'extract' is not defined
