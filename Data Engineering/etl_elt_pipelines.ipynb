# %% [markdown]
# ### **ETL processes**

# %%
def load(data_frame, target_table):
    # loading data from sql
    data_frame.to_sql(name=target_table, con=POSTGRES_CONNECTION)
    print(f"Loading data to the {target_table} table")

def extract(file_name):
    print(f"Extracting data from {file_name}")
    return pd.read_csv(file_name)

extracted_data = extract(file_name="data.csv") # extracting the data from the raw data file
transformed_data = transform(data_frame=extracted_data) # transforming the extracted data
load(data_frame=transformed_data, target_table="cleaned_data") # loadingg the transformed data to a sql table
# Out:
# Extracting data from data.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 10
#       7     print(f"Extracting data from {file_name}")
#       8     return pd.read_csv(file_name)
# ---> 10 extracted_data = extract(file_name="data.csv")
#      11 transformed_data = transform(data_frame=extracted_data)
#      12 load(data_frame=transformed_data, target_table="cleaned_data")
#
# Cell In[4], line 8, in extract(file_name)
#       6 def extract(file_name):
#       7     print(f"Extracting data from {file_name}")
# ----> 8     return pd.read_csv(file_name)
#
# ...

# %% [markdown]
# ### **ELT processes**

# %%
def transform(source_table, target_table):
    data_warehouse.run_sql("""
    CREATE TABLE {target_table} AS
        SELECT
            <field-name>, <field-name>, ...
        FROM {source_table};
        """)

extracted_data = extract(file_name="data.csv")
load(data_frame=extracted_data, table_name="raw_data")
transform(source_table="raw_data", target_table="cleaned_data")
# ELT processes are generally found in a data platform that leverages a data warehouse
# Out:
# Extracting data from data.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       1 def transform(source_table, target_table):
#       2     data_warehouse.run_sql("""
#       3     CREATE TABLE {target_table} AS
#       4         SELECT
#       5             <field-name>, <field-name>, ...
#       6         FROM {source_table};
#       7         """)
# ----> 9 extracted_data = extract(file_name="data.csv")
#      10 load(data_frame=extracted_data, table_name="raw_data")
#      11 transform(source_table="raw_data", target_table="cleaned_data")
#
# Cell In[4], line 8, in extract(file_name)
#       6 def extract(file_name):
#       7     print(f"Extracting data from {file_name}")
# ----> 8     return pd.read_csv(file_name)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("Customer_Data.csv")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
# filtering
# loc allows for the rows and columns of a dataframe to be filtered
df.loc[df["TENURE"] == "12", :] 
# filtering the dataframe to only include rows that have "TENURE" "12"
# The colon ":" denotes that all columns should be kept
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # filtering
#       2 # loc allows for the rows and columns of a dataframe to be filtered
# ----> 3 df.loc[df["TENURE"] > "8"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...

# %%
list(df.columns)
# Out:
# ['CUST_ID',
#  'BALANCE',
#  'BALANCE_FREQUENCY',
#  'PURCHASES',
#  'ONEOFF_PURCHASES',
#  'INSTALLMENTS_PURCHASES',
#  'CASH_ADVANCE',
#  'PURCHASES_FREQUENCY',
#  'ONEOFF_PURCHASES_FREQUENCY',
#  'PURCHASES_INSTALLMENTS_FREQUENCY',
#  'CASH_ADVANCE_FREQUENCY',
#  'CASH_ADVANCE_TRX',
#  'PURCHASES_TRX',
#  'CREDIT_LIMIT',
#  'PAYMENTS',
#  'MINIMUM_PAYMENTS',
#  'PRC_FULL_PAYMENT',
#  'TENURE']
