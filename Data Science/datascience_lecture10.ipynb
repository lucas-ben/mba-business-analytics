# %% [markdown]
# ## **Recommendation Engines**

# %% [markdown]
# Challenges of engines:
#
# - Sharing (revenue is the main goal of limiting sharing & it is difficult to learn preferences when too many people share the same account)
#     - Another issue is the cold start problem.
#     - Recommendation systems have a diversity problem and recommend the same or similar content
#     - How to balance quality over brain rot.
#     - **Growth data science teams spend time talking about how algorithms change**
#     - Product recommendation engines are missing personal information. They rely heavily on your product browsing to recommend products to you.
#     - Engines are optimized for some metric like engagement.
#
#
#
# - Observe myself because it'll teach me about people and I can start to get a sense of what type of data points to collect or how to frame the problem.
#
# - There is product-based filtering (content based) or people-based filtering (collaborative). These are older, traditional filtering methods for recommendation engines.
