# %% [markdown]
# ## **Recommendation Engines**

# %% [markdown]
# Challenges of engines: Sharing (revenue is the main goal of limiting sharing & it is difficult to learn preferences when too many people share the same account)
