# %% [markdown]
# ## **Creating a simulated observational data set where weight loss is the continuous dependent variable, influenced by both numeric and categorical variables**
#
# - y: How much weight a person will lose
#
# - X: starting body weight, height, diet, daily calories burned, perform cardio, weight lift, nightly sleep
#
# - Sample Size: 50,000
#
# - Determine relationship structure:
#     - Define how each predictor affects weight loss
#         - Linear vs non-linear relationships
#         - Interaction effects
#
# - Add random error

# %%
import numpy as np
import pandas as pd

# %%
# generating random numeric data
np.random.seed(1992)
np.random.normal()

# %%
# generating random categrorical data
np.random.choice()
