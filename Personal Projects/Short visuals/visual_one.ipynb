# %%
import pandas as pd
from pybaseball import cache, batting_stats

# %%
df = batting_stats(2016, 2025, qual=250)

# %%
df.to_csv('/Users/lucasben/Desktop/visual_one.csv')

# %%
df2 = batting_stats(2007, 2015, qual=250)

# %%
df3 = batting_stats(2000,2006, qual=250)

# %%
df4 = batting_stats(1990, 1999, qual=250)

# %%
df5 = batting_stats(1980, 1989, qual=250)

# %%
df = pd.concat([df, df2, df3, df4, df5])
df.to_csv('/Users/lucasben/Desktop/batting_season_data_1980-2025.csv')

# %%
df4['Season'].describe()
# Out:
# count    2773.000000
# mean     1994.622791
# std         2.913832
# min      1990.000000
# 25%      1992.000000
# 50%      1995.000000
# 75%      1997.000000
# max      1999.000000
# Name: Season, dtype: float64
